# %%
import main
import scipy
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
filename = 'sp500.mat'
q_value = 0.8
prob_x1 = 0.2

# %%
n, data = main.read_data(filename)
message_y_x, message_x_fort, message_x_back, message_x_y = main.main(filename, q_value, prob_x1)
print message_x_fort[0]
print message_y_x[0]
# Out:
# [ 0.76470588  0.23529412]
# [ 0.8  0.2]

# %%
x_good = main.compute_prob(n, message_y_x, message_x_fort, message_x_back)
print x_good[:, 1]
plt.plot(x_good[:, 1])
plt.show()
plt.plot(range(n), data, 'r', range(n), x_good[:, 1] * 60, 'b')
plt.show()
plt.plot(np.cumsum(data), 'r', (x_good[:, 1] - .5) * 10, 'b')
# Out:
# [ 0.07700527  0.02733625  0.03912799  0.08725118  0.30003432  0.0928598
#   0.05268215  0.07236099  0.20437323  0.80075152  0.93489907  0.96454271
#   0.96873214  0.95863915  0.90734911  0.67808859  0.87073093  0.87014521
#   0.6747695   0.90123157  0.94585632  0.92764304  0.79802303  0.21134288
#   0.08562532  0.08562352  0.2113327   0.79797734  0.92756571  0.94566677
#   0.90055005  0.6719043   0.86531023  0.86050387  0.64466823  0.85035024
#   0.8407723   0.59039324  0.8842244 ]
# [<matplotlib.lines.Line2D at 0x3aa5110>,
#  <matplotlib.lines.Line2D at 0x3aa5610>]

# %%
plt.plot(message_x_y[:, 1], 'b', (data + 2.) / 4., 'r')
plt.show()

# %%
message_x_y /= np.sum(message_y_x, axis=1).reshape((-1, 1))

# %%
message_x_y
# Out:
# array([[  2.89803308e-12,   1.29650648e-12],
#        [  1.62184107e-12,   1.29650648e-12],
#        [  1.19007864e-12,   1.29650648e-12],
#        [  1.13671650e-12,   1.29650648e-12],
#        [  1.29650648e-12,   2.17666997e-12],
#        [  1.02065134e-12,   1.29650648e-12],
#        [  9.21102240e-13,   1.29650648e-12],
#        [  9.98060301e-13,   1.29650648e-12],
#        [  1.33459137e-12,   1.29650648e-12],
#        [  1.29650648e-12,   1.28689209e-12],
#        [  1.29650648e-12,   9.35218392e-13],
#        [  1.29650648e-12,   8.11630650e-13],
#        [  1.29650648e-12,   7.82732568e-13],
#        [  1.29650648e-12,   8.17332568e-13],
#        [  1.29650648e-12,   9.52776679e-13],
#        [  2.24556887e-12,   1.29650648e-12],
#        [  1.29650648e-12,   1.06029244e-12],
#        [  1.29650648e-12,   1.06649608e-12],
#        [  2.22026197e-12,   1.29650648e-12],
#        [  1.29650648e-12,   1.00049420e-12],
#        [  1.29650648e-12,   9.07335703e-13],
#        [  1.29650648e-12,   9.80537939e-13],
#        [  1.29650648e-12,   1.29911284e-12],
#        [  1.37390838e-12,   1.29650648e-12],
#        [  1.07907809e-12,   1.29650648e-12],
#        [  1.07899418e-12,   1.29650648e-12],
#        [  1.37356611e-12,   1.29650648e-12],
#        [  1.29650648e-12,   1.30008290e-12],
#        [  1.29650648e-12,   9.82182974e-13],
#        [  1.29650648e-12,   9.10431439e-13],
#        [  1.29650648e-12,   1.00738220e-12],
#        [  2.20314691e-12,   1.29650648e-12],
#        [  1.29650648e-12,   1.09502342e-12],
#        [  1.29650648e-12,   1.11353650e-12],
#        [  2.12762531e-12,   1.29650648e-12],
#        [  1.29650648e-12,   1.14978223e-12],
#        [  1.29650648e-12,   1.17902146e-12],
#        [  2.00834779e-12,   1.29650648e-12],
#        [  1.29650648e-12,   1.33844065e-12]])
