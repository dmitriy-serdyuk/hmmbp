# %%
import main
import scipy
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
filename = 'sp500.mat'
q_value = 0.9
prob_x1 = 0.2

# %%
n, data = main.read_data(filename)
message_y_x, message_x_fort, message_x_back, message_x_y = main.main(filename, q_value, prob_x1)

# %%
plt.plot(range(n), data, 'r', range(n), x_good * 60, 'b')
plt.show()

# %%
x_good = main.compute_prob(n, message_y_x, message_x_fort, message_x_back)
print x_good
plt.plot(x_good)
plt.show()
# Out:
# [ 0.01636335  0.0042553   0.00251552  0.00274135  0.01980233  0.00220043
#   0.00272682  0.00265903  0.00281731  0.01157755  0.01013938  0.00935649
#   0.00912824  0.00942527  0.01028578  0.00131338  0.0182547   0.0176699
#   0.00202426  0.0136132   0.01238492  0.01196128  0.01228781  0.00148961
#   0.00279773  0.00265398  0.00279771  0.01340786  0.01228941  0.01196322
#   0.01238735  0.00151292  0.01815906  0.01760068  0.00201904  0.0130112
#   0.01167883  0.00123414  0.12406503]

# %%
plt.plot(message_x_back)
