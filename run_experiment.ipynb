# %%
import main
import scipy
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
filename = 'sp500.mat'
q_value = 0.7
prob_x1 = 0.2

# %%
n, data = main.read_data(filename)
message_y_x, message_x_fort, message_x_back, message_x_y = main.main(filename, q_value, prob_x1)
print message_x_fort[0]
print message_y_x[0]
# Out:
# [ 0.74193548  0.25806452]
# [ 0.7  0.3]

# %%
x_good = main.compute_prob(n, message_y_x, message_x_fort, message_x_back)
print x_good[:, 1]
plt.plot(x_good[:, 1])
plt.show()
plt.plot(range(n), data, 'r', range(n), x_good[:, 1] * 60, 'b')
plt.show()
plt.plot(np.cumsum(data), 'r', (x_good[:, 1] - .5) * 10, 'b')
# Out:
# [ 0.15689018  0.06705157  0.09218677  0.14698891  0.29060951  0.16687146
#   0.13826379  0.17390839  0.31227879  0.70272717  0.84586137  0.89617545
#   0.90797666  0.89400281  0.83917103  0.68429779  0.79564659  0.79313665
#   0.67405885  0.81986494  0.85758834  0.82794637  0.69894451  0.33134265
#   0.21195576  0.21192179  0.33120409  0.69855178  0.82728038  0.85633504
#   0.81707635  0.66712985  0.78158741  0.77409083  0.63654856  0.75941369
#   0.74757372  0.588249    0.78479279]
# [<matplotlib.lines.Line2D at 0x35f5d10>,
#  <matplotlib.lines.Line2D at 0x35f5790>]

# %%
plt.plot(message_x_y[:, 1], 'b', (data + 2.) / 4., 'r')
plt.show()
